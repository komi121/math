# %%
import numpy
import matplotlib.pyplot as mat_plot

# %%
x = numpy.linspace(1, 30, 1000)
mat_plot.plot(x, numpy.cos(x))

# %%
x = numpy.linspace(1, 100, 1000)
mat_plot.plot(x, numpy.cos(0.2 * x))
